# %%
from google.colab import drive  #mount google drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import json    #import json,csv,pandas and io 
import csv
import pandas as pd
import io
import matplotlib.pyplot as plt
import time
from datetime import datetime
import datetime
# %matplotlib inline
import seaborn as sns
import plotly.express as px
import folium

# %%
from google.colab import files   # to import files in colab

# %% [markdown]
# **WMATA API TransitAnalysis**

# %%
url ="https://api.wmata.com/Bus.svc/json/jBusPositions?RouteID=70"

import requests
import json

headers = {
     'content-type' : 'application/json',
     'api_key': 'ae979f0db7684af58ac62e684b994b02'
}

response = requests.get(url , headers=headers)

with open('data.json' ,'w') as outfile:
  json.dump(response.json() , outfile) 

with open('data.txt' ,'w') as outfile:
  json.dump(json.dumps(response.json(), indent =4 ,sort_keys =True) ,outfile)

print(json.dumps(response.json(), indent =4 ,sort_keys =True) ,outfile)
# Out:
# {
#     "BusPositions": [
#         {
#             "BlockNumber": "M-721",
#             "DateTime": "2022-11-27T00:58:38",
#             "Deviation": 0.0,
#             "DirectionNum": 1,
#             "DirectionText": "SOUTH",
#             "Lat": 38.88844472711737,
#             "Lon": -77.02190399169922,
#             "RouteID": "70",
#             "TripEndTime": "2022-11-27T01:00:00",
#             "TripHeadsign": "L'ENFANT PLAZA STATION",
#             "TripID": "51242070",
#             "TripStartTime": "2022-11-27T00:07:00",
#             "VehicleID": "7233"
#         },
#         {
#             "BlockNumber": "M-724",
#             "DateTime": "2022-11-27T00:58:32",
#             "Deviation": 6.0,
#             "DirectionNum": 0,
#             "DirectionText": "NORTH",
#             "Lat": 38.96143301602068,
#             "Lon": -77.02799172237002,
#             "RouteID": "70",
#             "TripEndTime": "2022-11-27T01:07:00",
#             "TripHeadsign": "SILVER SPRING STATION",
#             "TripID": "25306070",
#             "TripStartTime": "2022-11-27T00:15:00",
#             "VehicleID": "4534"
#         },
#         {
#             "BlockNumber": "M-722",
#             "DateTime": "2022-11-27T00:58:31",
#             "Deviation": -5.0,
#             "DirectionNum": 1,
#             "DirectionText": "SOUTH",
#             "Lat": 38.91925811767578,
#             "Lon": -77.02189636230469,
#             "RouteID": "70",
#             "TripEndTime": "2022-11-27T01:20:00",
#             "TripHeadsign": "L'ENFANT PLAZA STATION",
#             "TripID": "47051070",
#             "TripStartTime": "2022-11-27T00:27:00",
#             "VehicleID": "4467"
#         },
#         {
#             "BlockNumber": "M-726",
#             "DateTime": "2022-11-27T00:58:27",
#             "Deviation": 1.0,
#             "DirectionNum": 0,
#             "DirectionText": "NORTH",
#             "Lat": 38.93106079101563,
#             "Lon": -77.02352905273438,
#             "RouteID": "70",
#             "TripEndTime": "2022-11-27T01:27:00",
#             "TripHeadsign": "SILVER SPRING STATION",
#             "TripID": "10844070",
#             "TripStartTime": "2022-11-27T00:35:00",
#             "VehicleID": "4531"
#         },
#         {
#             "BlockNumber": "M-725",
#             "DateTime": "2022-11-27T00:58:36",
#             "Deviation": 1.0,
#             "DirectionNum": 1,
#             "DirectionText": "SOUTH",
#             "Lat": 38.96420729787726,
#             "Lon": -77.02776416979339,
#             "RouteID": "70",
#             "TripEndTime": "2022-11-27T01:25:00",
#             "TripHeadsign": "L'ENFANT PLAZA STATION",
#             "TripID": "51798070",
#             "TripStartTime": "2022-11-27T00:47:00",
#             "VehicleID": "4539"
#         },
#         {
#             "BlockNumber": "M-720",
#             "DateTime": "2022-11-27T00:58:37",
#             "Deviation": 5.0,
#             "DirectionNum": 0,
#             "DirectionText": "NORTH",
#             "Lat": 38.9001637334409,
#             "Lon": -77.02192588474439,
#             "RouteID": "70",
#             "TripEndTime": "2022-11-27T01:32:00",
#             "TripHeadsign": "SILVER SPRING STATION",
#             "TripID": "12392070",
#             "TripStartTime": "2022-11-27T00:50:00",
#             "VehicleID": "7218"
#         },
#         {
#             "BlockNumber": "M-723",
#             "DateTime": "2022-11-27T00:58:33",
#             "Deviation": 0.0,
#             "DirectionNum": 1,
#             "DirectionText": "SOUTH",
#             "Lat": 38.99341201782227,
#             "Lon": -77.03011322021484,
#             "RouteID": "70",
#             "TripEndTime": "2022-11-27T01:45:00",
#             "TripHeadsign": "L'ENFANT PLAZA STATION",
#             "TripID": "36312070",
#             "TripStartTime": "2022-11-27T01:07:00",
#             "VehicleID": "7211"
#         }
#     ]
# } <_io.TextIOWrapper name='data.txt' mode='w' encoding='UTF-8'>

# %%
df = pd.read_json('data.json')  #read JSON file using pandas library

# %%
df  #nested dataFrame
# Out:
#                                         BusPositions
# 0  {'VehicleID': '7233', 'Lat': 38.88844472711737...
# 1  {'VehicleID': '4534', 'Lat': 38.96143301602068...
# 2  {'VehicleID': '4467', 'Lat': 38.91925811767578...
# 3  {'VehicleID': '4531', 'Lat': 38.93106079101563...
# 4  {'VehicleID': '4539', 'Lat': 38.96420729787726...
# 5  {'VehicleID': '7218', 'Lat': 38.9001637334409,...
# 6  {'VehicleID': '7211', 'Lat': 38.99341201782227...

# %%
df  #BusPositions dataframe
#NB: The dataframe is in a nested list in a single column Bus Positions
# Out:
#                                         BusPositions
# 0  {'VehicleID': '7233', 'Lat': 38.88844472711737...
# 1  {'VehicleID': '4534', 'Lat': 38.96143301602068...
# 2  {'VehicleID': '4467', 'Lat': 38.91925811767578...
# 3  {'VehicleID': '4531', 'Lat': 38.93106079101563...
# 4  {'VehicleID': '4539', 'Lat': 38.96420729787726...
# 5  {'VehicleID': '7218', 'Lat': 38.9001637334409,...
# 6  {'VehicleID': '7211', 'Lat': 38.99341201782227...

# %%
df2=pd.concat([df.BusPositions.apply(pd.Series), df.drop('BusPositions', axis=1)], axis=1)  #Flatten nested attribute BusPositions in the dataFrame
df2  #rename the df with Flattened BusPositions to df2
# Out:
#   VehicleID        Lat        Lon  Deviation             DateTime    TripID  \
# 0      7233  38.888445 -77.021904        0.0  2022-11-27T00:58:38  51242070
# 1      4534  38.961433 -77.027992        6.0  2022-11-27T00:58:32  25306070
# 2      4467  38.919258 -77.021896       -5.0  2022-11-27T00:58:31  47051070
# 3      4531  38.931061 -77.023529        1.0  2022-11-27T00:58:27  10844070
# 4      4539  38.964207 -77.027764        1.0  2022-11-27T00:58:36  51798070
# 5      7218  38.900164 -77.021926        5.0  2022-11-27T00:58:37  12392070
# 6      7211  38.993412 -77.030113        0.0  2022-11-27T00:58:33  36312070
#
#   RouteID  DirectionNum DirectionText            TripHeadsign  \
# 0      70             1         SOUTH  L'ENFANT PLAZA STATION
# 1      70             0         NORTH   SILVER SPRING STATION
# 2      70             1         SOUTH  L'ENFANT PLAZA STATION
# 3      70             0         NORTH   SILVER SPRING STATION
# 4      70             1         SOUTH  L'ENFANT PLAZA STATION
# 5      70             0         NORTH   SILVER SPRING STATION
# 6      70             1         SOUTH  L'ENFANT PLAZA STATION
#
#          TripStartTime          TripEndTime BlockNumber
# 0  2022-11-27T00:07:00  2022-11-27T01:00:00       M-721
# 1  2022-11-27T00:15:00  2022-11-27T01:07:00       M-724
# 2  2022-11-27T00:27:00  2022-11-27T01:20:00       M-722
# 3  2022-11-27T00:35:00  2022-11-27T01:27:00       M-726
# 4  2022-11-27T00:47:00  2022-11-27T01:25:00       M-725
# 5  2022-11-27T00:50:00  2022-11-27T01:32:00       M-720
# 6  2022-11-27T01:07:00  2022-11-27T01:45:00       M-723

# %%
df2.head (5) #dataframe head
# Out:
#   VehicleID        Lat        Lon  Deviation             DateTime    TripID  \
# 0      7233  38.888445 -77.021904        0.0  2022-11-27T00:58:38  51242070
# 1      4534  38.961433 -77.027992        6.0  2022-11-27T00:58:32  25306070
# 2      4467  38.919258 -77.021896       -5.0  2022-11-27T00:58:31  47051070
# 3      4531  38.931061 -77.023529        1.0  2022-11-27T00:58:27  10844070
# 4      4539  38.964207 -77.027764        1.0  2022-11-27T00:58:36  51798070
#
#   RouteID  DirectionNum DirectionText            TripHeadsign  \
# 0      70             1         SOUTH  L'ENFANT PLAZA STATION
# 1      70             0         NORTH   SILVER SPRING STATION
# 2      70             1         SOUTH  L'ENFANT PLAZA STATION
# 3      70             0         NORTH   SILVER SPRING STATION
# 4      70             1         SOUTH  L'ENFANT PLAZA STATION
#
#          TripStartTime          TripEndTime BlockNumber
# 0  2022-11-27T00:07:00  2022-11-27T01:00:00       M-721
# 1  2022-11-27T00:15:00  2022-11-27T01:07:00       M-724
# 2  2022-11-27T00:27:00  2022-11-27T01:20:00       M-722
# 3  2022-11-27T00:35:00  2022-11-27T01:27:00       M-726
# 4  2022-11-27T00:47:00  2022-11-27T01:25:00       M-725

# %%
df2.describe() #Describing the dataframe
# Out:
#              Lat        Lon  Deviation  DirectionNum
# count   7.000000   7.000000   7.000000      7.000000
# mean   38.936854 -77.025018   1.142857      0.571429
# std     0.037824   0.003502   3.625308      0.534522
# min    38.888445 -77.030113  -5.000000      0.000000
# 25%    38.909711 -77.027878   0.000000      0.000000
# 50%    38.931061 -77.023529   1.000000      1.000000
# 75%    38.962820 -77.021915   3.000000      1.000000
# max    38.993412 -77.021896   6.000000      1.000000

# %%
df2.columns # MetroBus Columns/ Variables
# Out:
# Index(['VehicleID', 'Lat', 'Lon', 'Deviation', 'DateTime', 'TripID', 'RouteID',
#        'DirectionNum', 'DirectionText', 'TripHeadsign', 'TripStartTime',
#        'TripEndTime', 'BlockNumber'],
#       dtype='object')

# %% [markdown]
# **Average time it takes for a Bus to complete a Route**

# %%
df2['start'] = pd.to_datetime(df2[ 'TripStartTime'])   #Define start and stop between TripStartTime and TripEndTime 
df2['stop'] = pd.to_datetime(df2[ 'TripEndTime'])

# %%
df2['delta'] = df2['stop'] - df2['start']  #Difference between start and stop

# %%
df2['delta']  #Bustrips time differnce
# Out:
# 0   0 days 00:53:00
# 1   0 days 00:52:00
# 2   0 days 00:53:00
# 3   0 days 00:52:00
# 4   0 days 00:38:00
# 5   0 days 00:42:00
# 6   0 days 00:38:00
# Name: delta, dtype: timedelta64[ns]

# %%
df2['delta'].sum()  #The sum of the bus trips
# Out:
# Timedelta('0 days 05:28:00')

# %%
average_time = df2['delta'].sum() /7  #Average time it take for a Bus to complete a Route
print(average_time)
# Out:
# 0 days 00:46:51.428571428

# %% [markdown]
# **Average time** it takes for a Bus to complete a route is **46 minutes and 51 seconds**

# %% [markdown]
# **Map Plot Visualization of BlockNumbers and Locations**

# %%
df2 = df2[["Lat", "Lon", "BlockNumber"]]  #Mapping the locations and the BlockNumber

# %%
map = folium.Map(location=[df2.Lat.mean(), df2.Lon.mean()], zoom_start=11, control_scale=True) 
#Creating the Map  using latitude and longitude coordinates

# %%
for index, location_info in df2.iterrows():      #Adding the Transit Route  Points
    folium.Marker([location_info["Lat"], location_info["Lon"]], popup=location_info["BlockNumber"]).add_to(map)

# %%
map  #plot the Transit map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_13233b7b441f46bca12fc222637d638f {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_13233b7b441f46bca12fc222637d638f&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_13233b7b441f46bca12fc222637d638f = L.map(
#                 &quot;map_13233b7b441f46bca12fc222637d638f&quot;,
#                 {
#                     center: [38.9368542429957, -77.02501777198015],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 11,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_13233b7b441f46bca12fc222637d638f);
#
#
#
#
#
#             var tile_layer_2e1469ee2b55e1085f3620657b90d302 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_13233b7b441f46bca12fc222637d638f);
#
#
#             var marker_b79e6bb599cdb5e3b7fbabaa54971b81 = L.marker(
#                 [38.88844472711737, -77.02190399169922],
#                 {}
#             ).addTo(map_13233b7b441f46bca12fc222637d638f);
#
#
#         var popup_ae368190254294282876b79146ddd18b = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_edf31ceee1fc718aed7afdcd363e9296 = $(`&lt;div id=&quot;html_edf31ceee1fc718aed7afdcd363e9296&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;M-721&lt;/div&gt;`)[0];
#             popup_ae368190254294282876b79146ddd18b.setContent(html_edf31ceee1fc718aed7afdcd363e9296);
#
#
#         marker_b79e6bb599cdb5e3b7fbabaa54971b81.bindPopup(popup_ae368190254294282876b79146ddd18b)
#         ;
#
#
#
#
#             var marker_39cae8704dbcde40b5a18bb4bf77f366 = L.marker(
#                 [38.96143301602068, -77.02799172237002],
#                 {}
#             ).addTo(map_13233b7b441f46bca12fc222637d638f);
#
#
#         var popup_23fe56ac2750d474b0bc8b4306533980 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_025dab058a26a0df96b9a52a4c8e17e0 = $(`&lt;div id=&quot;html_025dab058a26a0df96b9a52a4c8e17e0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;M-724&lt;/div&gt;`)[0];
#             popup_23fe56ac2750d474b0bc8b4306533980.setContent(html_025dab058a26a0df96b9a52a4c8e17e0);
#
#
#         marker_39cae8704dbcde40b5a18bb4bf77f366.bindPopup(popup_23fe56ac2750d474b0bc8b4306533980)
#         ;
#
#
#
#
#             var marker_0ade7e6b37c5d366893eb6ebe259f9a9 = L.marker(
#                 [38.91925811767578, -77.02189636230469],
#                 {}
#             ).addTo(map_13233b7b441f46bca12fc222637d638f);
#
#
#         var popup_71a790653161abe22b0c8e48a10ff4c3 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_6c2d9f5707b55d78ee1a3bc1068eda40 = $(`&lt;div id=&quot;html_6c2d9f5707b55d78ee1a3bc1068eda40&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;M-722&lt;/div&gt;`)[0];
#             popup_71a790653161abe22b0c8e48a10ff4c3.setContent(html_6c2d9f5707b55d78ee1a3bc1068eda40);
#
#
#         marker_0ade7e6b37c5d366893eb6ebe259f9a9.bindPopup(popup_71a790653161abe22b0c8e48a10ff4c3)
#         ;
#
#
#
#
#             var marker_2ead7139f7687fc6bb78703da23c23df = L.marker(
#                 [38.93106079101563, -77.02352905273438],
#                 {}
#             ).addTo(map_13233b7b441f46bca12fc222637d638f);
#
#
#         var popup_52b67e76b89fb59e4d2c6839771b04c1 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_138cfae2feecaf98676b9977faeb1081 = $(`&lt;div id=&quot;html_138cfae2feecaf98676b9977faeb1081&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;M-726&lt;/div&gt;`)[0];
#             popup_52b67e76b89fb59e4d2c6839771b04c1.setContent(html_138cfae2feecaf98676b9977faeb1081);
#
#
#         marker_2ead7139f7687fc6bb78703da23c23df.bindPopup(popup_52b67e76b89fb59e4d2c6839771b04c1)
#         ;
#
#
#
#
#             var marker_6f01f29e0974602745f61d9d49187fac = L.marker(
#                 [38.96420729787726, -77.02776416979339],
#                 {}
#             ).addTo(map_13233b7b441f46bca12fc222637d638f);
#
#
#         var popup_17eea003903e2acfd71800c51f8a75e6 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_3232d42a90e78239d20e8ce96ffa94fa = $(`&lt;div id=&quot;html_3232d42a90e78239d20e8ce96ffa94fa&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;M-725&lt;/div&gt;`)[0];
#             popup_17eea003903e2acfd71800c51f8a75e6.setContent(html_3232d42a90e78239d20e8ce96ffa94fa);
#
#
#         marker_6f01f29e0974602745f61d9d49187fac.bindPopup(popup_17eea003903e2acfd71800c51f8a75e6)
#         ;
#
#
#
#
#             var marker_db6ba5322993b6cf9c012cdffc218087 = L.marker(
#                 [38.9001637334409, -77.02192588474439],
#                 {}
#             ).addTo(map_13233b7b441f46bca12fc222637d638f);
#
#
#         var popup_f3d48b8379b1b767895a12e6aa2d66ab = L.popup({&q

# %% [markdown]
# ***Estimate of the Speed of Bus ***

# %%
pip install haversine  #install haversine to calculate distance between two points
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting haversine
#   Downloading haversine-2.7.0-py2.py3-none-any.whl (6.9 kB)
# Installing collected packages: haversine
# Successfully installed haversine-2.7.0

# %%
from haversine import inverse_haversine, Direction  #import haversine 
from math import pi

# %%
from haversine import haversine  #Distance in miles between Bus Trip 1  to Bus Trip 2
haversine((38.888445,-77.021904 ),(38.961433,-77.027992 ), unit='mi')


=5.053597035114924 Miles
# Out:
# 5.053597035114924

# %% [markdown]
# **Formula  = Speed = Distance /Time**

# %%
Distance_of_Trip_One_to_Two = 5.053597035114924  #Distance in Miles
Hourly_Average_time_per_trip= 0.766666666666666718  #Time in 46:51.428571428 minutes

# %%
Speed = Distance_of_Trip_One_to_Two / Hourly_Average_time_per_trip 
print(Speed)
# Out:
# 6.591648306671639

# %% [markdown]
# **Speed = 6.59 ~ 6.6miles /hour**
